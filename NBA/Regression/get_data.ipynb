# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from nba_api.stats.static import players
from nba_api.stats.endpoints import playergamelog
from nba_api.stats.library.parameters import SeasonAll

# %%
all_games = pd.read_csv('all_games.csv')

# %%
all_games['TS%'] = all_games['PTS'] / (2 * (all_games['FGA'] + (0.44 * all_games['FTA'])))

# %%
block_size = 30 # amount of games of context we are using for average stats
recent_size = 5 # amount of games of recent context we are using

def context_player(df):
    df['PTS_LB'] = df['PTS'].rolling(window=5, min_periods=1).mean().shift(-block_size)
    df['AST_LB'] = df['AST'].rolling(window=5, min_periods=1).mean().shift(-block_size)
    df['REB_LB'] = df['REB'].rolling(window=5, min_periods=1).mean().shift(-block_size)
    df['TS%_LR'] = df['TS%'].rolling(window=5, min_periods=1).mean().shift(-recent_size)
    df['MIN_LR'] = df['MIN'].rolling(window=5, min_periods=1).mean().shift(-recent_size)
    return df

all_games_plus = all_games.groupby('Player_ID').apply(context_player)
all_games_plus = all_games_plus.dropna()
all_games_plus.head()
# Out:
# /var/folders/1j/ycj6sm297qj2d2b1b3pb8k980000gn/T/ipykernel_89160/961708231.py:12: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   all_games_plus = all_games.groupby('Player_ID').apply(context_player)
#                  SEASON_ID  Player_ID   Game_ID     GAME_DATE      MATCHUP WL  \
# Player_ID
# 2544      73591      22023       2544  22301195  APR 14, 2024    LAL @ NOP  W
#           73592      22023       2544  22301177  APR 12, 2024    LAL @ MEM  W
#           73593      22023       2544  22301155  APR 09, 2024  LAL vs. GSW  L
#           73594      22023       2544  22301127  APR 06, 2024  LAL vs. CLE  W
#           73595      22023       2544  22301103  APR 03, 2024    LAL @ WAS  W
#
#                  MIN  FGM  FGA  FG_PCT  ...  PF  PTS  PLUS_MINUS  \
# Player_ID                               ...
# 2544      73591   38   11   20   0.550  ...   0   28          19
#           73592   41   13   20   0.650  ...   1   37          -3
#           73593   36   14   22   0.636  ...   0   33          -6
#           73594   36   10   18   0.556  ...   1   24          10
#           73595   36    9   18   0.500  ...   2   25           9
#
#                  VIDEO_AVAILABLE       TS%  PTS_LB  AST_LB  REB_LB    TS%_LR  \
# Player_ID
# 2544      73591                1  0.618375    25.6     9.4     8.8  0.679944
#           73592                1  0.744767    26.4     9.4     8.8  0.734657
#           73593                1  0.681818    27.2     8.8     9.2  0.714572
#           73594                1  0.594059    27.6     8.4     9.6  0.717841
#           73595                1  0.569217    25.4     7.2     7.0  0.719450
#
#                  MIN_LR
# Player_ID
# 2544      73591    35.6
#           73592    34.8
#           73593    34.6
#           73594    34.4
#           73595    34.8
#
# [5 rows x 33 columns]

# %%
by_game = all_games_plus.sort_values(by=['Game_ID'])
by_game.tail()
# Out:
#                   SEASON_ID  Player_ID   Game_ID     GAME_DATE      MATCHUP  \
# Player_ID
# 1627752   124958      22023    1627752  22301230  DEC 07, 2023  LAL vs. NOP
# 1627742   70555       22023    1627742  22301230  DEC 07, 2023    NOP @ LAL
# 203469    161307      22023     203469  22301230  DEC 07, 2023    NOP @ LAL
# 1629627   158319      22023    1629627  22301230  DEC 07, 2023    NOP @ LAL
# 1626156   131852      22023    1626156  22301230  DEC 07, 2023  LAL vs. NOP
#
#                  WL  MIN  FGM  FGA  FG_PCT  ...  PF  PTS  PLUS_MINUS  \
# Player_ID                                   ...
# 1627752   124958  W   23    5    9   0.556  ...   3   15          23
# 1627742   70555   L   31    4   13   0.308  ...   3    9         -33
# 203469    161307  L   12    0    1   0.000  ...   2    2          -5
# 1629627   158319  L   26    6    8   0.750  ...   3   13         -33
# 1626156   131852  W   22    6   10   0.600  ...   1   14          23
#
#                   VIDEO_AVAILABLE       TS%  PTS_LB  AST_LB  REB_LB    TS%_LR  \
# Player_ID
# 1627752   124958                1  0.833333    12.6     2.0     2.6  0.678032
# 1627742   70555                 1  0.324207    29.8     8.2     6.6  0.603765
# 203469    161307                1  0.531915     5.2     0.6     3.8  0.560812
# 1629627   158319                1  0.610902    30.0     4.2     8.0  0.695781
# 1626156   131852                1  0.700000    15.8     6.0     2.0  0.570587
#
#                   MIN_LR
# Player_ID
# 1627752   124958    28.0
# 1627742   70555     36.0
# 203469    161307    10.4
# 1629627   158319    30.2
# 1626156   131852    28.0
#
# [5 rows x 33 columns]

# %%
by_game = by_game[by_game['MIN'] >= 20]
by_game['Player_Count'] = by_game.groupby('Game_ID')['Game_ID'].transform('count') # don't need this column
by_game.tail()
# Out:
#                   SEASON_ID  Player_ID   Game_ID     GAME_DATE      MATCHUP  \
# Player_ID
# 202685    148034      22023     202685  22301230  DEC 07, 2023    NOP @ LAL
# 1627752   124958      22023    1627752  22301230  DEC 07, 2023  LAL vs. NOP
# 1627742   70555       22023    1627742  22301230  DEC 07, 2023    NOP @ LAL
# 1629627   158319      22023    1629627  22301230  DEC 07, 2023    NOP @ LAL
# 1626156   131852      22023    1626156  22301230  DEC 07, 2023  LAL vs. NOP
#
#                  WL  MIN  FGM  FGA  FG_PCT  ...  PTS  PLUS_MINUS  \
# Player_ID                                   ...
# 202685    148034  L   23    3    9   0.333  ...    9         -25
# 1627752   124958  W   23    5    9   0.556  ...   15          23
# 1627742   70555   L   31    4   13   0.308  ...    9         -33
# 1629627   158319  L   26    6    8   0.750  ...   13         -33
# 1626156   131852  W   22    6   10   0.600  ...   14          23
#
#                   VIDEO_AVAILABLE       TS%  PTS_LB  AST_LB  REB_LB    TS%_LR  \
# Player_ID
# 202685    148034                1  0.455466    14.4     2.6    12.4  0.721348
# 1627752   124958                1  0.833333    12.6     2.0     2.6  0.678032
# 1627742   70555                 1  0.324207    29.8     8.2     6.6  0.603765
# 1629627   158319                1  0.610902    30.0     4.2     8.0  0.695781
# 1626156   131852                1  0.700000    15.8     6.0     2.0  0.570587
#
#                   MIN_LR  Player_Count
# Player_ID
# 202685    148034    31.6            14
# 1627752   124958    28.0            14
# 1627742   70555     36.0            14
# 1629627   158319    30.2            14
# 1626156   131852    28.0            14
#
# [5 rows x 34 columns]

# %%
by_game_filtered = by_game[by_game['Player_Count'] >= 10]
by_game_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 59306 entries, (203493, 22531) to (1626156, 131852)
# Data columns (total 34 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SEASON_ID        59306 non-null  int64
#  1   Player_ID        59306 non-null  int64
#  2   Game_ID          59306 non-null  int64
#  3   GAME_DATE        59306 non-null  object
#  4   MATCHUP          59306 non-null  object
#  5   WL               59306 non-null  object
#  6   MIN              59306 non-null  int64
#  7   FGM              59306 non-null  int64
#  8   FGA              59306 non-null  int64
#  9   FG_PCT           59306 non-null  float64
#  10  FG3M             59306 non-null  int64
#  11  FG3A             59306 non-null  int64
#  12  FG3_PCT          59306 non-null  float64
#  13  FTM              59306 non-null  int64
#  14  FTA              59306 non-null  int64
#  15  FT_PCT           59306 non-null  float64
#  16  OREB             59306 non-null  int64
#  17  DREB             59306 non-null  int64
#  18  REB              59306 non-null  int64
#  19  AST              59306 non-null  int64
#  20  STL              59306 non-null  int64
#  21  BLK              59306 non-null  int64
#  22  TOV              59306 non-null  int64
#  23  PF               59306 non-null  int64
#  24  PTS              59306 non-null  int64
#  25  PLUS_MINUS       59306 non-null  int64
#  26  VIDEO_AVAILABLE  59306 non-null  int64
#  27  TS%              59306 non-null  float64
#  28  PTS_LB           59306 non-null  float64
#  29  AST_LB           59306 non-null  float64
#  30  REB_LB           59306 non-null  float64
#  31  TS%_LR           59306 non-null  float64
#  32  MIN_LR           59306 non-null  float64
#  33  Player_Count     59306 non-null  int64
# dtypes: float64(9), int64(22), object(3)
# memory usage: 21.0+ MB

# %%
by_game_filtered['HOME'] = by_game_filtered['MATCHUP'].apply(lambda x: 0 if '@' in x else 1)
by_game_filtered.head()
# Out:
# /var/folders/1j/ycj6sm297qj2d2b1b3pb8k980000gn/T/ipykernel_89160/99764706.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   by_game_filtered['HOME'] = by_game_filtered['MATCHUP'].apply(lambda x: 0 if '@' in x else 1)
#                  SEASON_ID  Player_ID   Game_ID     GAME_DATE      MATCHUP WL  \
# Player_ID
# 203493    22531      22015     203493  21500879  FEB 28, 2016  DET vs. TOR  W
# 203484    24956      22015     203484  21500879  FEB 28, 2016  DET vs. TOR  W
# 203083    39433      22015     203083  21500879  FEB 28, 2016  DET vs. TOR  W
# 202704    72802      22015     202704  21500879  FEB 28, 2016  DET vs. TOR  W
# 202687    14496      22015     202687  21500879  FEB 28, 2016    TOR @ DET  L
#
#                  MIN  FGM  FGA  FG_PCT  ...  PLUS_MINUS  VIDEO_AVAILABLE  \
# Player_ID                               ...
# 203493    22531   26    3    6   0.500  ...           5                1
# 203484    24956   36    7   10   0.700  ...          30                1
# 203083    39433   30    6   10   0.600  ...          19                1
# 202704    72802   28    7   12   0.583  ...          19                1
# 202687    14496   22    1    2   0.500  ...           1                1
#
#                       TS%  PTS_LB  AST_LB  REB_LB    TS%_LR  MIN_LR  \
# Player_ID
# 203493    22531  0.666667     0.4     0.2     0.2  0.449153    10.6
# 203484    24956  0.766284    18.6     2.2     3.4  0.538383    33.6
# 203083    39433  0.554734    18.8     0.8    15.8  0.511153    33.0
# 202704    72802  0.690407    18.0     6.0     4.2  0.637372    30.6
# 202687    14496  0.500000     6.0     0.6    13.8  0.593357    20.0
#
#                  Player_Count  HOME
# Player_ID
# 203493    22531            10     1
# 203484    24956            10     1
# 203083    39433            10     1
# 202704    72802            10     1
# 202687    14496            10     0
#
# [5 rows x 35 columns]

# %%
by_game_sorted = by_game_filtered.sort_values(by=['Game_ID', 'HOME'])
by_game_sorted.head(10)
# Out:
#                   SEASON_ID  Player_ID   Game_ID     GAME_DATE      MATCHUP  \
# Player_ID
# 202687    14496       22015     202687  21500879  FEB 28, 2016    TOR @ DET
# 201942    36361       22015     201942  21500879  FEB 28, 2016    TOR @ DET
# 202709    80528       22015     202709  21500879  FEB 28, 2016    TOR @ DET
# 202685    148567      22015     202685  21500879  FEB 28, 2016    TOR @ DET
# 203493    22531       22015     203493  21500879  FEB 28, 2016  DET vs. TOR
# 203484    24956       22015     203484  21500879  FEB 28, 2016  DET vs. TOR
# 203083    39433       22015     203083  21500879  FEB 28, 2016  DET vs. TOR
# 202704    72802       22015     202704  21500879  FEB 28, 2016  DET vs. TOR
# 202699    60718       22015     202699  21500879  FEB 28, 2016  DET vs. TOR
# 202694    108572      22015     202694  21500879  FEB 28, 2016  DET vs. TOR
#
#                  WL  MIN  FGM  FGA  FG_PCT  ...  PLUS_MINUS  VIDEO_AVAILABLE  \
# Player_ID                                   ...
# 202687    14496   L   22    1    2   0.500  ...           1                1
# 201942    36361   L   35    9   21   0.429  ...         -29                1
# 202709    80528   L   20    4   10   0.400  ...         -13                1
# 202685    148567  L   21    5    6   0.833  ...         -27                1
# 203493    22531   W   26    3    6   0.500  ...           5                1
# 203484    24956   W   36    7   10   0.700  ...          30                1
# 203083    39433   W   30    6   10   0.600  ...          19                1
# 202704    72802   W   28    7   12   0.583  ...          19                1
# 202699    60718   W   25    5    9   0.556  ...          21                1
# 202694    108572  W   32    5   10   0.500  ...          22                1
#
#                        TS%  PTS_LB  AST_LB  REB_LB    TS%_LR  MIN_LR  \
# Player_ID
# 202687    14496   0.500000     6.0     0.6    13.8  0.593357    20.0
# 201942    36361   0.448029    25.4     5.0     5.2  0.483794    35.6
# 202709    80528   0.478927     4.6     2.8     2.4  0.617517    25.0
# 202685    148567  0.854037     7.2     0.6     6.4  0.684573    27.2
# 203493    22531   0.666667     0.4     0.2     0.2  0.449153    10.6
# 203484    24956   0.766284    18.6     2.2     3.4  0.538383    33.6
# 203083    39433   0.554734    18.8     0.8    15.8  0.511153    33.0
# 202704    72802   0.690407    18.0     6.0     4.2  0.637372    30.6
# 202699    60718   0.708502    16.2     1.6     6.8  0.602394    33.0
# 202694    108572  0.595238    14.2     2.0     4.6  0.402973    36.6
#
#                   Player_Count  HOME
# Player_ID
# 202687    14496             10     0
# 201942    36361             10     0
# 202709    80528             10     0
# 202685    148567            10     0
# 203493    22531             10     1
# 203484    24956             10     1
# 203083    39433             10     1
# 202704    72802             10     1
# 202699    60718             10     1
# 202694    108572            10     1
#
# [10 rows x 35 columns]

# %%
by_game_sorted['Team_Count'] = by_game_sorted.groupby(['Game_ID', 'HOME']).transform('size')
by_game_sorted.head(22)
# Out:
#                   SEASON_ID  Player_ID   Game_ID     GAME_DATE      MATCHUP  \
# Player_ID
# 202687    14496       22015     202687  21500879  FEB 28, 2016    TOR @ DET
# 201942    36361       22015     201942  21500879  FEB 28, 2016    TOR @ DET
# 202709    80528       22015     202709  21500879  FEB 28, 2016    TOR @ DET
# 202685    148567      22015     202685  21500879  FEB 28, 2016    TOR @ DET
# 203493    22531       22015     203493  21500879  FEB 28, 2016  DET vs. TOR
# 203484    24956       22015     203484  21500879  FEB 28, 2016  DET vs. TOR
# 203083    39433       22015     203083  21500879  FEB 28, 2016  DET vs. TOR
# 202704    72802       22015     202704  21500879  FEB 28, 2016  DET vs. TOR
# 202699    60718       22015     202699  21500879  FEB 28, 2016  DET vs. TOR
# 202694    108572      22015     202694  21500879  FEB 28, 2016  DET vs. TOR
# 202704    72783       22015     202704  21501166  APR 06, 2016    DET @ ORL
# 202699    60699       22015     202699  21501166  APR 06, 2016    DET @ ORL
# 203083    39414       22015     203083  21501166  APR 06, 2016    DET @ ORL
# 202694    108553      22015     202694  21501166  APR 06, 2016    DET @ ORL
# 203484    24938       22015     203484  21501166  APR 06, 2016    DET @ ORL
# 203493    22519       22015     203493  21501166  APR 06, 2016    DET @ ORL
# 202696    150659      22015     202696  21501166  APR 06, 2016  ORL vs. DET
# 203932    50692       22015     203932  21501166  APR 06, 2016  ORL vs. DET
# 203095    44747       22015     203095  21501166  APR 06, 2016  ORL vs. DET
# 203506    115700      22015     203506  21501166  APR 06, 2016  ORL vs. DET
# 202693    107310      22015     202693  21501182  APR 08, 2016    WAS @ DET
# 202066    141878      22015     202066  21501182  APR 08, 2016    WAS @ DET
#
#                  WL  MIN  FGM  FGA  FG_PCT  ...  VIDEO_AVAILABLE       TS%  \
# Player_ID                                   ...
# 202687    14496   L   22    1    2   0.500  ...                1  0.500000
# 201942    36361   L   35    9   21   0.429  ...                1  0.448029
# 202709    80528   L   20    4   10   0.400  ...                1  0.478927
# 202685    148567  L   21    5    6   0.833  ...                1  0.854037
# 203493    22531   W   26    3    6   0.500  ...                1  0.666667
# 203484    24956   W   36    7   10   0.700  ...                1  0.766284
# 203083    39433   W   30    6   10   0.600  ...                1  0.554734
# 202704    72802   W   28    7   12   0.583  ...                1  0.690407
# 202699    60718   W   25    5    9   0.556  ...                1  0.708502
# 202694    108572  W   32    5   10   0.500  ...                1  0.595238
# 202704    72783   W   32    7   18   0.389  ...                1  0.525394
# 202699    60699   W   30    5   11   0.455  ...                1  0.547138
# 203083    39414   W   33    5   14   0.357  ...                1  0.390625
# 202694    108553  W   33    3   11   0.273  ...                1  0.352665
# 203484    24938   W   36    7   10   0.700  ...                1  0.795053
# 203493    22519   W   27    5    9   0.556  ...                1  0.722222
# 202696    150659  L   27    7   14   0.500  ...                1  0.504032
# 203932    50692   L   32    3   10   0.300  ...                1  0.275735
# 203095    44747   L   32    7   15   0.467  ...                1  0.552326
# 203506    115700  L   39    5   13   0.385  ...                1  0.497512
# 202693    107310  L   37   10   20   0.500  ...                1  0.605175
# 202066    141878  L   21    1    6   0.167  ...                1  0.166667
#
#                   PTS_LB  AST_LB  REB_LB    TS%_LR  MIN_LR  Player_Count  \
# Player_ID
# 202687    14496      6.0     0.6    13.8  0.593357    20.0            10
# 201942    36361     25.4     5.0     5.2  0.483794    35.6            10
# 202709    80528      4.6     2.8     2.4  0.617517    25.0            10
# 202685    148567     7.2     0.6     6.4  0.684573    27.2            10
# 203493    22531      0.4     0.2     0.2  0.449153    10.6            10
# 203484    24956     18.6     2.2     3.4  0.538383    33.6            10
# 203083    39433     18.8     0.8    15.8  0.511153    33.0            10
# 202704    72802     18.0     6.0     4.2  0.637372    30.6            10
# 202699    60718     16.2     1.6     6.8  0.602394    33.0            10
# 202694    108572    14.2     2.0     4.6  0.402973    36.6            10
# 202704    72783     19.2     4.2     1.8  0.432010    30.8            10
# 202699    60699     13.0     1.0     6.0  0.603313    35.2            10
# 203083    39414     15.2     0.8    14.0  0.499922    31.6            10
# 202694    108553    14.0     4.2     4.8  0.553973    36.8            10
# 203484    24938     15.2     1.4     5.2  0.380992    36.0            10
# 203493    22519      0.8     0.2     0.6  0.956159     7.4            10
# 202696    150659    18.6     3.4     7.4  0.592536    28.4            10
# 203932    50692      7.0     2.4     9.2  0.569381    27.0            10
# 203095    44747     12.0     2.2     2.6  0.652924    31.4            10
# 203506    115700    19.2     4.0     3.8  0.495396    36.0            10
# 202693    107310    20.6     4.6     7.6  0.520813    30.8            10
# 202066    141878     3.2     1.4     2.4  0.579373    21.0            10
#
#                   HOME  Team_Count
# Player_ID
# 202687    14496      0           4
# 201942    36361      0           4
# 202709    80528      0           4
# 202685    148567     0           4
# 203493    22531      1           6
# 203484    24956      1           6
# 203083    39433      1           6
# 202704    72802      1           6
# 202699    60718      1           6
# 202694    108572     1           6
# 202704    72783      0           6
# 202699    60699      0           6
# 203083    39414      0           6
# 202694    108553     0           6
# 203484    24938      0           6
# 203493    22519      0           6
# 202696    150659     1           4
# 203932    50692      1           4
# 203095    44747      1           4
# 203506    115700     1           4
# 202693    107310     0           4
# 202066    141878     0           4
#
# [22 rows x 36 columns]

# %%
by_game_sorted['Opp_Count'] = by_game_sorted['Player_Count'] - by_game_sorted['Team_Count']
by_game_sorted = by_game_sorted[by_game_sorted['Team_Count'] > 4]
by_game_sorted = by_game_sorted[by_game_sorted['Opp_Count'] > 4]
by_game_sorted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 49973 entries, (202696, 150635) to (1626156, 131852)
# Data columns (total 37 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SEASON_ID        49973 non-null  int64
#  1   Player_ID        49973 non-null  int64
#  2   Game_ID          49973 non-null  int64
#  3   GAME_DATE        49973 non-null  object
#  4   MATCHUP          49973 non-null  object
#  5   WL               49973 non-null  object
#  6   MIN              49973 non-null  int64
#  7   FGM              49973 non-null  int64
#  8   FGA              49973 non-null  int64
#  9   FG_PCT           49973 non-null  float64
#  10  FG3M             49973 non-null  int64
#  11  FG3A             49973 non-null  int64
#  12  FG3_PCT          49973 non-null  float64
#  13  FTM              49973 non-null  int64
#  14  FTA              49973 non-null  int64
#  15  FT_PCT           49973 non-null  float64
#  16  OREB             49973 non-null  int64
#  17  DREB             49973 non-null  int64
#  18  REB              49973 non-null  int64
#  19  AST              49973 non-null  int64
#  20  STL              49973 non-null  int64
#  21  BLK              49973 non-null  int64
#  22  TOV              49973 non-null  int64
#  23  PF               49973 non-null  int64
#  24  PTS              49973 non-null  int64
#  25  PLUS_MINUS       49973 non-null  int64
#  26  VIDEO_AVAILABLE  49973 non-null  int64
#  27  TS%              49973 non-null  float64
#  28  PTS_LB           49973 non-null  float64
#  29  AST_LB           49973 non-null  float64
#  30  REB_LB           49973 non-null  float64
#  31  TS%_LR           49973 non-null  float64
#  32  MIN_LR           49973 non-null  float64
#  33  Player_Count     49973 non-null  int64
#  34  HOME             49973 non-null  int64
#  35  Team_Count       49973 non-null  int64
#  36  Opp_Count        49973 non-null  int64
# dtypes: float64(9), int64(25), object(3)
# memory usage: 19.7+ MB

# %%
by_game_sorted.head(20)
# Out:
#                   SEASON_ID  Player_ID   Game_ID     GAME_DATE      MATCHUP  \
# Player_ID
# 202696    150635      22016     202696  21600300  DEC 04, 2016    ORL @ DET
# 203932    50670       22016     203932  21600300  DEC 04, 2016    ORL @ DET
# 203095    44722       22016     203095  21600300  DEC 04, 2016    ORL @ DET
# 202687    14452       22016     202687  21600300  DEC 04, 2016    ORL @ DET
# 201145    55200       22016     201145  21600300  DEC 04, 2016    ORL @ DET
# 203083    39391       22016     203083  21600300  DEC 04, 2016  DET vs. ORL
# 202397    138344      22016     202397  21600300  DEC 04, 2016  DET vs. ORL
# 203484    24914       22016     203484  21600300  DEC 04, 2016  DET vs. ORL
# 202704    72781       22016     202704  21600300  DEC 04, 2016  DET vs. ORL
# 202699    60675       22016     202699  21600300  DEC 04, 2016  DET vs. ORL
# 202694    108529      22016     202694  21600300  DEC 04, 2016  DET vs. ORL
# 201143    67679       22016     201143  21600322  DEC 07, 2016    BOS @ ORL
# 1626179   131001      22016    1626179  21600322  DEC 07, 2016    BOS @ ORL
# 203935    137713      22016     203935  21600322  DEC 07, 2016    BOS @ ORL
# 203482    116460      22016     203482  21600322  DEC 07, 2016    BOS @ ORL
# 203109    32897       22016     203109  21600322  DEC 07, 2016    BOS @ ORL
# 203095    44720       22016     203095  21600322  DEC 07, 2016  ORL vs. BOS
# 202687    14450       22016     202687  21600322  DEC 07, 2016  ORL vs. BOS
# 203932    50668       22016     203932  21600322  DEC 07, 2016  ORL vs. BOS
# 201145    55198       22016     201145  21600322  DEC 07, 2016  ORL vs. BOS
#
#                  WL  MIN  FGM  FGA  FG_PCT  ...       TS%  PTS_LB  AST_LB  \
# Player_ID                                   ...
# 202696    150635  W   28    8   14   0.571  ...  0.571429    20.6     2.0
# 203932    50670   W   22    4    8   0.500  ...  0.512295    12.2     2.2
# 203095    44722   W   32    1    7   0.143  ...  0.317259    17.6     2.0
# 202687    14452   W   30    2    3   0.667  ...  0.644330     5.0     0.0
# 201145    55200   W   30    6   11   0.545  ...  0.636364    11.2     0.4
# 203083    39391   L   35    5   11   0.455  ...  0.391850    18.4     0.4
# 202397    138344  L   25    5   10   0.500  ...  0.505515    11.8     6.6
# 203484    24914   L   34    4   12   0.333  ...  0.375000    13.2     2.4
# 202704    72781   L   23    7   12   0.583  ...  0.698758    18.6     4.8
# 202699    60675   L   35    5   12   0.417  ...  0.442122    16.0     3.4
# 202694    108529  L   35    7   12   0.583  ...  0.815217    20.8     2.6
# 201143    67679   W   29    3    9   0.333  ...  0.464684    17.8     2.2
# 1626179   131001  W   26    6   13   0.462  ...  0.542005     3.2     1.0
# 203935    137713  W   23    5    7   0.714  ...  0.824873     6.6     2.8
# 203482    116460  W   20    4    8   0.500  ...  0.533175     8.4     1.4
# 203109    32897   W   30    6   10   0.600  ...  0.696721    19.2     2.8
# 203095    44720   L   29    4   14   0.286  ...  0.420673    21.6     3.0
# 202687    14450   L   26    1    2   0.500  ...  0.531915     4.8     0.2
# 203932    50668   L   26    2    9   0.222  ...  0.253036    10.6     2.2
# 201145    55198   L   22    1    5   0.200  ...  0.300000    11.4     1.0
#
#                   REB_LB    TS%_LR  MIN_LR  Player_Count  HOME  Team_Count  \
# Player_ID
# 202696    150635     7.2  0.526287    29.4            11     0           5
# 203932    50670      6.8  0.450893    24.4            11     0           5
# 203095    44722      1.4  0.624145    33.8            11     0           5
# 202687    14452      5.0  0.414706    32.6            11     0           5
# 201145    55200      3.2  0.424553    24.6            11     0           5
# 203083    39391     15.4  0.535754    27.6            11     1           6
# 202397    138344     3.4  0.615155    31.0            11     1           6
# 203484    24914      4.6  0.575956    33.2            11     1           6
# 202704    72781      1.8  0.540076    32.4            11     1           6
# 202699    60675      7.2  0.663966    34.2            11     1           6
# 202694    108529     7.0  0.537834    32.0            11     1           6
# 201143    67679      6.8  0.575967    34.4            10     0           5
# 1626179   131001     4.0  0.275385    13.6            10     0           5
# 203935    137713     4.6  0.462257    27.8            10     0           5
# 203482    116460     3.4  0.761639    17.8            10     0           5
# 203109    32897      5.6  0.601223    34.8            10     0           5
# 203095    44720      3.0  0.572127    31.8            10     1           5
# 202687    14450      5.8  0.480827    32.2            10     1           5
# 203932    50668      5.2  0.570631    23.0            10     1           5
# 201145    55198      2.2  0.599546    26.0            10     1           5
#
#                   Opp_Count
# Player_ID
# 202696    150635          6
# 203932    50670           6
# 203095    44722           6
# 202687    14452           6
# 201145    55200           6
# 203083    39391           5
# 202397    138344          5
# 203484    24914           5
# 202704    72781           5
# 202699    60675           5
# 202694    108529          5
# 201143    67679           5
# 1626179   131001          5
# 203935    137713          5
# 203482    116460          5
# 203109    32897           5
# 203095    44720           5
# 202687    14450           5
# 203932    50668           5
# 201145    55198           5
#
# [20 rows x 37 columns]

# %%
by_game_sorted = by_game_sorted.sort_values(by=['Game_ID', 'HOME', 'MIN'])

def filter_t5(group):
    return group.tail(5)

by_game_sorted_filtered = by_game_sorted.groupby(['Game_ID', 'HOME']).apply(filter_t5).reset_index(drop=True)
by_game_sorted_filtered.head(20)
# Out:
# /var/folders/1j/ycj6sm297qj2d2b1b3pb8k980000gn/T/ipykernel_89160/407112599.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   by_game_sorted_filtered = by_game_sorted.groupby(['Game_ID', 'HOME']).apply(filter_t5).reset_index(drop=True)
#     SEASON_ID  Player_ID   Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 0       22016     203932  21600300  DEC 04, 2016    ORL @ DET  W   22    4
# 1       22016     202696  21600300  DEC 04, 2016    ORL @ DET  W   28    8
# 2       22016     202687  21600300  DEC 04, 2016    ORL @ DET  W   30    2
# 3       22016     201145  21600300  DEC 04, 2016    ORL @ DET  W   30    6
# 4       22016     203095  21600300  DEC 04, 2016    ORL @ DET  W   32    1
# 5       22016     202397  21600300  DEC 04, 2016  DET vs. ORL  L   25    5
# 6       22016     203484  21600300  DEC 04, 2016  DET vs. ORL  L   34    4
# 7       22016     203083  21600300  DEC 04, 2016  DET vs. ORL  L   35    5
# 8       22016     202699  21600300  DEC 04, 2016  DET vs. ORL  L   35    5
# 9       22016     202694  21600300  DEC 04, 2016  DET vs. ORL  L   35    7
# 10      22016     203482  21600322  DEC 07, 2016    BOS @ ORL  W   20    4
# 11      22016     203935  21600322  DEC 07, 2016    BOS @ ORL  W   23    5
# 12      22016    1626179  21600322  DEC 07, 2016    BOS @ ORL  W   26    6
# 13      22016     201143  21600322  DEC 07, 2016    BOS @ ORL  W   29    3
# 14      22016     203109  21600322  DEC 07, 2016    BOS @ ORL  W   30    6
# 15      22016     201145  21600322  DEC 07, 2016  ORL vs. BOS  L   22    1
# 16      22016     202687  21600322  DEC 07, 2016  ORL vs. BOS  L   26    1
# 17      22016     203932  21600322  DEC 07, 2016  ORL vs. BOS  L   26    2
# 18      22016     202696  21600322  DEC 07, 2016  ORL vs. BOS  L   27    5
# 19      22016     203095  21600322  DEC 07, 2016  ORL vs. BOS  L   29    4
#
#     FGA  FG_PCT  ...       TS%  PTS_LB  AST_LB  REB_LB    TS%_LR  MIN_LR  \
# 0     8   0.500  ...  0.512295    12.2     2.2     6.8  0.450893    24.4
# 1    14   0.571  ...  0.571429    20.6     2.0     7.2  0.526287    29.4
# 2     3   0.667  ...  0.644330     5.0     0.0     5.0  0.414706    32.6
# 3    11   0.545  ...  0.636364    11.2     0.4     3.2  0.424553    24.6
# 4     7   0.143  ...  0.317259    17.6     2.0     1.4  0.624145    33.8
# 5    10   0.500  ...  0.505515    11.8     6.6     3.4  0.615155    31.0
# 6    12   0.333  ...  0.375000    13.2     2.4     4.6  0.575956    33.2
# 7    11   0.455  ...  0.391850    18.4     0.4    15.4  0.535754    27.6
# 8    12   0.417  ...  0.442122    16.0     3.4     7.2  0.663966    34.2
# 9    12   0.583  ...  0.815217    20.8     2.6     7.0  0.537834    32.0
# 10    8   0.500  ...  0.533175     8.4     1.4     3.4  0.761639    17.8
# 11    7   0.714  ...  0.824873     6.6     2.8     4.6  0.462257    27.8
# 12   13   0.462  ...  0.542005     3.2     1.0     4.0  0.275385    13.6
# 13    9   0.333  ...  0.464684    17.8     2.2     6.8  0.575967    34.4
# 14   10   0.600  ...  0.696721    19.2     2.8     5.6  0.601223    34.8
# 15    5   0.200  ...  0.300000    11.4     1.0     2.2  0.599546    26.0
# 16    2   0.500  ...  0.531915     4.8     0.2     5.8  0.480827    32.2
# 17    9   0.222  ...  0.253036    10.6     2.2     5.2  0.570631    23.0
# 18   14   0.357  ...  0.403226    20.2     2.0     9.4  0.528485    27.0
# 19   14   0.286  ...  0.420673    21.6     3.0     3.0  0.572127    31.8
#
#     Player_Count  HOME  Team_Count  Opp_Count
# 0             11     0           5          6
# 1             11     0           5          6
# 2             11     0           5          6
# 3             11     0           5          6
# 4             11     0           5          6
# 5             11     1           6          5
# 6             11     1           6          5
# 7             11     1           6          5
# 8             11     1           6          5
# 9             11     1           6          5
# 10            10     0           5          5
# 11            10     0           5          5
# 12            10     0           5          5
# 13            10     0           5          5
# 14            10     0           5          5
# 15            10     1           5          5
# 16            10     1           5          5
# 17            10     1           5          5
# 18            10     1           5          5
# 19            10     1           5          5
#
# [20 rows x 37 columns]

# %%
by_game_sorted_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40970 entries, 0 to 40969
# Data columns (total 37 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SEASON_ID        40970 non-null  int64
#  1   Player_ID        40970 non-null  int64
#  2   Game_ID          40970 non-null  int64
#  3   GAME_DATE        40970 non-null  object
#  4   MATCHUP          40970 non-null  object
#  5   WL               40970 non-null  object
#  6   MIN              40970 non-null  int64
#  7   FGM              40970 non-null  int64
#  8   FGA              40970 non-null  int64
#  9   FG_PCT           40970 non-null  float64
#  10  FG3M             40970 non-null  int64
#  11  FG3A             40970 non-null  int64
#  12  FG3_PCT          40970 non-null  float64
#  13  FTM              40970 non-null  int64
#  14  FTA              40970 non-null  int64
#  15  FT_PCT           40970 non-null  float64
#  16  OREB             40970 non-null  int64
#  17  DREB             40970 non-null  int64
#  18  REB              40970 non-null  int64
#  19  AST              40970 non-null  int64
#  20  STL              40970 non-null  int64
#  21  BLK              40970 non-null  int64
#  22  TOV              40970 non-null  int64
#  23  PF               40970 non-null  int64
#  24  PTS              40970 non-null  int64
#  25  PLUS_MINUS       40970 non-null  int64
#  26  VIDEO_AVAILABLE  40970 non-null  int64
#  27  TS%              40970 non-null  float64
#  28  PTS_LB           40970 non-null  float64
#  29  AST_LB           40970 non-null  float64
#  30  REB_LB           40970 non-null  float64
#  31  TS%_LR           40970 non-null  float64
#  32  MIN_LR           40970 non-null  float64
#  33  Player_Count     40970 non-null  int64
#  34  HOME             40970 non-null  int64
#  35  Team_Count       40970 non-null  int64
#  36  Opp_Count        40970 non-null  int64
# dtypes: float64(9), int64(25), object(3)
# memory usage: 11.6+ MB

# %%
from nba_api.stats.endpoints import boxscoreadvancedv2
from nba_api.stats.endpoints import boxscoretraditionalv2
from nba_api.stats.endpoints import boxscoresummaryv2

# %%
bsa = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id='0021800470')
bsa = bsa.get_data_frames()[0]
bsa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GAME_ID            22 non-null     object
#  1   TEAM_ID            22 non-null     int64
#  2   TEAM_ABBREVIATION  22 non-null     object
#  3   TEAM_CITY          22 non-null     object
#  4   PLAYER_ID          22 non-null     int64
#  5   PLAYER_NAME        22 non-null     object
#  6   NICKNAME           22 non-null     object
#  7   START_POSITION     22 non-null     object
#  8   COMMENT            22 non-null     object
#  9   MIN                21 non-null     object
#  10  E_OFF_RATING       21 non-null     float64
#  11  OFF_RATING         22 non-null     float64
#  12  E_DEF_RATING       21 non-null     float64
#  13  DEF_RATING         22 non-null     float64
#  14  E_NET_RATING       21 non-null     float64
#  15  NET_RATING         22 non-null     float64
#  16  AST_PCT            21 non-null     float64
#  17  AST_TOV            21 non-null     float64
#  18  AST_RATIO          21 non-null     float64
#  19  OREB_PCT           22 non-null     float64
#  20  DREB_PCT           22 non-null     float64
#  21  REB_PCT            22 non-null     float64
#  22  TM_TOV_PCT         21 non-null     float64
#  23  EFG_PCT            21 non-null     float64
#  24  TS_PCT             21 non-null     float64
#  25  USG_PCT            22 non-null     float64
#  26  E_USG_PCT          22 non-null     float64
#  27  E_PACE             21 non-null     float64
#  28  PACE               21 non-null     float64
#  29  PACE_PER40         21 non-null     float64
#  30  POSS               22 non-null     int64
#  31  PIE                21 non-null     float64
# dtypes: float64(21), int64(3), object(8)
# memory usage: 5.6+ KB

# %%
headers  = {
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'x-nba-stats-token': 'true',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'x-nba-stats-origin': 'stats',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'cors',
    'Referer': 'https://stats.nba.com/',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
}

# %%
game_ids = all_games['Game_ID'].unique().tolist()
for i in range(len(game_ids)):
    game_ids[i] = f"{game_ids[i]:010}"
len(game_ids)
# Out:
# 19055

# %%
all_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162339 entries, 0 to 162338
# Data columns (total 28 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SEASON_ID        162339 non-null  int64
#  1   Player_ID        162339 non-null  int64
#  2   Game_ID          162339 non-null  int64
#  3   GAME_DATE        162339 non-null  object
#  4   MATCHUP          162339 non-null  object
#  5   WL               162339 non-null  object
#  6   MIN              162339 non-null  int64
#  7   FGM              162339 non-null  int64
#  8   FGA              162339 non-null  int64
#  9   FG_PCT           162339 non-null  float64
#  10  FG3M             162339 non-null  int64
#  11  FG3A             162339 non-null  int64
#  12  FG3_PCT          162339 non-null  float64
#  13  FTM              162339 non-null  int64
#  14  FTA              162339 non-null  int64
#  15  FT_PCT           162339 non-null  float64
#  16  OREB             162339 non-null  int64
#  17  DREB             162339 non-null  int64
#  18  REB              162339 non-null  int64
#  19  AST              162339 non-null  int64
#  20  STL              162339 non-null  int64
#  21  BLK              162339 non-null  int64
#  22  TOV              162339 non-null  int64
#  23  PF               162339 non-null  int64
#  24  PTS              162339 non-null  int64
#  25  PLUS_MINUS       162339 non-null  int64
#  26  VIDEO_AVAILABLE  162339 non-null  int64
#  27  TS%              157862 non-null  float64
# dtypes: float64(4), int64(21), object(3)
# memory usage: 34.7+ MB

# %%
def get_box_scores(game_id):
    game_data_adv = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id=game_id, headers=headers, timeout=100)
    df_adv = game_data_adv.player_stats.get_data_frame()
    game_data_trad = boxscoretraditionalv2.BoxScoreTraditionalV2(game_id=game_id, headers=headers, timeout=100)
    df_trad = game_data_trad.player_stats.get_data_frame()
    game_data_sum = boxscoresummaryv2.BoxScoreSummaryV2(game_id=game_id, headers=headers, timeout=100)
    df_sum = game_data_sum.game_summary.get_data_frame()
    df_sum_plus = pd.concat([df_sum] * df_trad.shape[0], ignore_index=True)
    df_info = pd.concat([df_adv, df_trad, df_sum_plus], axis=1)
    df_info = df_info.T.drop_duplicates().T
    df_info = df_info[df_info['START_POSITION'].isin(['G', 'F', 'C'])]
    return df_info

def filter_box_scores(df):
    to_remove = [
        'WH_STATUS',
        'LIVE_PERIOD_TIME_BCAST',
        'NATL_TV_BROADCASTER_ABBREVIATION',
        'NICKNAME',
        'COMMENT',
        'E_OFF_RATING',
        'OFF_RATING',
        'E_DEF_RATING',
        'E_NET_RATING',
        'NET_RATING',
        'AST_PCT',
        'AST_TOV',
        'AST_RATIO',
        'OREB_PCT',
        'DREB_PCT',
        'REB_PCT',
        'TM_TOV_PCT',
        'EFG_PCT',
        'PIE',
        'FGM',
        'FGA',
        'FG_PCT',
        'FG3M',
        'FG3A',
        'FG3_PCT',
        'FTM',
        'FTA',
        'FT_PCT',
        'OREB',
        'DREB',
        'BLK',
        'STL',
        'TO',
        'PF',
        'PLUS_MINUS',
        'GAMECODE',
        'LIVE_PC_TIME',
        'LIVE_PERIOD',
        'TEAM_CITY',
        'GAME_STATUS_ID',
        'GAME_SEQUENCE',
        'GAME_STATUS_TEXT',
        'PACE_PER40',
        'E_USG_PCT',
        'E_PACE',
        'SEASON'
    ]

    for c in to_remove:
        if c in df:
            df = df.drop(c, axis=1)

    return df

def fix_time(df):
    df['YEAR'] = df['GAME_DATE_EST'].str[:4].astype(int)
    df['MONTH'] = df['GAME_DATE_EST'].str[5:7].astype(int)
    df['DAY'] = df['GAME_DATE_EST'].str[8:10].astype(int)
    # df = df.drop('GAME_DATE_EST', axis=1)
    return df

# %%
game_ids[:10]
# Out:
# ['0022301190',
#  '0022301175',
#  '0022301167',
#  '0022301139',
#  '0022301119',
#  '0022301112',
#  '0022301096',
#  '0022301082',
#  '0022301070',
#  '0022301053']

# %%
game_info = pd.DataFrame()
for i in range(639, 900):
    game_data = get_box_scores(game_ids[i])
    # game_data = filter_box_scores(game_data)
    # game_data = fix_time(game_data)
    game_info = pd.concat([game_info, game_data])
    if i % 10 == 0:
        print(i)
game_info.head(10)
# Out:
# 640
# 650
# 660
# 670
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[379], line 6
#       3 game_data = get_box_scores(game_ids[i])
#       4 # game_data = filter_box_scores(game_data)
#       5 # game_data = fix_time(game_data)
# ----> 6 game_info = pd.concat([game_info, game_data])
#       7 if i % 10 == 0:
#       8     print(i)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/reshape/concat.py:395, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380     copy = False
#     382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#    (...)
#     392     sort=sort,
#     393 )
# --> 395 return op.get_result()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/reshape/concat.py:680, in _Concatenator.get_result(self)
#     678         obj_labels = obj.axes[1 - ax]
#     679         if not new_labels.equals(obj_labels):
# --> 680             indexers[ax] = obj_labels.get_indexer(new_labels)
#     682     mgrs_indexers.append((obj._mgr, indexers))
#     684 new_data = concatenate_managers(
#     685     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     686 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:3885, in Index.get_indexer(self, target, method, limit, tolerance)
#    3882 self._check_indexing_method(method, limit, tolerance)
#    3884 if not self._index_as_unique:
# -> 3885     raise InvalidIndexError(self._requires_unique_msg)
#    3887 if len(target) == 0:
#    3888     return np.array([], dtype=np.intp)
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects

# %%
game_2 = pd.read_csv('better_games.csv')
game_3 = pd.concat([game_2, game_info])
game_3.to_csv('better_games.csv')
# game_info.info()

# %%
game_info = filter_box_scores(game_info)
game_info = fix_time(game_info)
game_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2000 entries, 0 to 19
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GAME_ID            2000 non-null   object
#  1   TEAM_ID            2000 non-null   object
#  2   TEAM_ABBREVIATION  2000 non-null   object
#  3   PLAYER_ID          2000 non-null   object
#  4   PLAYER_NAME        2000 non-null   object
#  5   START_POSITION     2000 non-null   object
#  6   MIN                2000 non-null   object
#  7   DEF_RATING         2000 non-null   object
#  8   TS_PCT             2000 non-null   object
#  9   USG_PCT            2000 non-null   object
#  10  PACE               2000 non-null   object
#  11  POSS               2000 non-null   object
#  12  REB                2000 non-null   object
#  13  AST                2000 non-null   object
#  14  PTS                2000 non-null   object
#  15  GAME_DATE_EST      2000 non-null   object
#  16  HOME_TEAM_ID       2000 non-null   object
#  17  VISITOR_TEAM_ID    2000 non-null   object
#  18  YEAR               2000 non-null   int64
#  19  MONTH              2000 non-null   int64
#  20  DAY                2000 non-null   int64
# dtypes: int64(3), object(18)
# memory usage: 343.8+ KB

# %%
game_info = game_info.sort_values(by=['PLAYER_ID', 'YEAR', 'MONTH', 'DAY'])
game_info.head(20)
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION PLAYER_ID        PLAYER_NAME  \
# 14  0022101028  1610612747               LAL      2544       LeBron James
# 0   0022101051  1610612747               LAL      2544       LeBron James
# 1   0022300701  1610612747               LAL      2544       LeBron James
# 2   0022101051  1610612747               LAL      2730      Dwight Howard
# 4   0022100613  1610612756               PHX    101108         Chris Paul
# 18  0022200762  1610612756               PHX    101108         Chris Paul
# 2   0022100928  1610612751               BKN    200746  LaMarcus Aldridge
# 4   0022101172  1610612748               MIA    200768         Kyle Lowry
# 19  0022200031  1610612748               MIA    200768         Kyle Lowry
# 19  0022200045  1610612748               MIA    200768         Kyle Lowry
# 4   0022301207  1610612748               MIA    200768         Kyle Lowry
# 3   0022300927  1610612755               PHI    200768         Kyle Lowry
# 3   0022300939  1610612755               PHI    200768         Kyle Lowry
# 12  0022100662  1610612748               MIA    200782        P.J. Tucker
# 13  0022100748  1610612748               MIA    200782        P.J. Tucker
# 1   0022100784  1610612748               MIA    200782        P.J. Tucker
# 1   0022200059  1610612755               PHI    200782        P.J. Tucker
# 2   0022200073  1610612755               PHI    200782        P.J. Tucker
# 14  0022201150  1610612755               PHI    200782        P.J. Tucker
# 1   0022300092  1610612755               PHI    200782        P.J. Tucker
#
#    START_POSITION           MIN DEF_RATING TS_PCT USG_PCT  ... POSS  REB  \
# 14              C  40.000000:20      114.8  0.679   0.277  ...   86  9.0
# 0               F  44.000000:41      120.7  0.619   0.327  ...   86  9.0
# 1               F  40.000000:18      105.2  0.604   0.256  ...   77  5.0
# 2               C  23.000000:53      143.2  0.689    0.13  ...   45  6.0
# 4               G  33.000000:15       92.4  0.631   0.189  ...   65  2.0
# 18              G  34.000000:40      110.0   0.72     0.2  ...   69  4.0
# 2               C  29.000000:30      116.7  0.601   0.206  ...   59  9.0
# 4               G  34.000000:33      113.0  0.722   0.169  ...   69  6.0
# 19              G  37.000000:15      116.0  0.666   0.188  ...   73  2.0
# 19              G  36.000000:06       93.2  0.359    0.12  ...   73  3.0
# 4               G  27.000000:34      107.5  0.375   0.098  ...   53  4.0
# 3               G  30.000000:57       94.8    0.5   0.152  ...   58  2.0
# 3               G  21.000000:07      135.0   0.25   0.119  ...   40  2.0
# 12              F  26.000000:39       90.2  0.833   0.055  ...   50  4.0
# 13              F  41.000000:17      113.2  0.458   0.122  ...   79  5.0
# 1               F  36.000000:02      116.9  0.505   0.181  ...   72  5.0
# 1               F  31.000000:27      122.2    0.4   0.162  ...   63  4.0
# 2               C  22.000000:33       93.0  0.833   0.063  ...   43  5.0
# 14              F  25.000000:43      114.0  0.643   0.148  ...   50  6.0
# 1               F  21.000000:12      110.0    1.5   0.049  ...   40  3.0
#
#      AST   PTS        GAME_DATE_EST HOME_TEAM_ID VISITOR_TEAM_ID  YEAR  MONTH  \
# 14   3.0  30.0  2022-03-14T00:00:00   1610612747      1610612761  2022      3
# 0    7.0  36.0  2022-03-18T00:00:00   1610612761      1610612747  2022      3
# 1    5.0  24.0  2024-02-03T00:00:00   1610612752      1610612747  2024      2
# 2    0.0   7.0  2022-03-18T00:00:00   1610612761      1610612747  2022      3
# 4   12.0  15.0  2022-01-11T00:00:00   1610612761      1610612756  2022      1
# 18   9.0  19.0  2023-01-30T00:00:00   1610612756      1610612761  2023      1
# 2    3.0  16.0  2022-03-01T00:00:00   1610612761      1610612751  2022      3
# 4   10.0  16.0  2022-04-03T00:00:00   1610612761      1610612748  2022      4
# 19   6.0  17.0  2022-10-22T00:00:00   1610612748      1610612761  2022     10
# 19   2.0   7.0  2022-10-24T00:00:00   1610612748      1610612761  2022     10
# 4    3.0   3.0  2023-12-06T00:00:00   1610612761      1610612748  2023     12
# 3    3.0   8.0  2024-03-10T00:00:00   1610612752      1610612755  2024      3
# 3    6.0   2.0  2024-03-12T00:00:00   1610612752      1610612755  2024      3
# 12   1.0   5.0  2022-01-17T00:00:00   1610612748      1610612761  2022      1
# 13   3.0  11.0  2022-01-29T00:00:00   1610612748      1610612761  2022      1
# 1    3.0  12.0  2022-02-01T00:00:00   1610612761      1610612748  2022      2
# 1    0.0   8.0  2022-10-26T00:00:00   1610612761      1610612755  2022     10
# 2    1.0   5.0  2022-10-28T00:00:00   1610612761      1610612755  2022     10
# 14   1.0   9.0  2023-03-31T00:00:00   1610612755      1610612761  2023      3
# 1    0.0   3.0  2023-10-28T00:00:00   1610612761      1610612755  2023     10
#
#     DAY
# 14   14
# 0    18
# 1     3
# 2    18
# 4    11
# 18   30
# 2     1
# 4     3
# 19   22
# 19   24
# 4     6
# 3    10
# 3    12
# 12   17
# 13   29
# 1     1
# 1    26
# 2    28
# 14   31
# 1    28
#
# [20 rows x 21 columns]

# %%
def get_adv(game_id):
    game_data_adv = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id=game_id, headers=headers, timeout=100)
    df_adv = game_data_adv.player_stats.get_data_frame()
    return df_adv
    
def get_trad(game_id):
    game_data_trad = boxscoretraditionalv2.BoxScoreTraditionalV2(game_id=game_id, headers=headers, timeout=100)
    df_trad = game_data_trad.player_stats.get_data_frame()
    return df_trad

def get_sum(game_id):
    game_data_sum = boxscoresummaryv2.BoxScoreSummaryV2(game_id=game_id, headers=headers, timeout=100)
    df_sum = game_data_sum.game_summary.get_data_frame()
    return df_sum

# %%
sum_data = pd.DataFrame()
for i in range(6751, len(game_ids)):
    game_sum = get_sum(game_ids[i])
    sum_data = pd.concat([sum_data, game_sum])
    if i % 50 == 0:
        print(i)
# trad_data.info()
# Out:
# 6800
# 6850
# 6900
# 6950
# 7000
# 7050
# 7100
# 7150
# 7200
# 7250
# 7300
# 7350
# 7400
# 7450
# 7500
# 7550
# 7600
# 7650
# 7700
# 7750
# 7800
# 7850
# 7900
# 7950
# 8000
# 8050
# 8100
# 8150
# 8200
# 8250
# 8300
# 8350
# 8400
# 8450
# 8500
# 8550
# 8600
# 8650
# 8700
# 8750
# 8800
# 8850
# 8900
# 8950
# 9000
# 9050
# 9100
# 9150
# 9200
# 9250
# 9300
# 9350
# 9400
# 9450
# 9500
# 9550
# 9600
# 9650
# 9700
# 9750
# 9800
# 9850
# 9900
# 9950
# 10000
# 10050
# 10100
# 10150
# 10200
# 10250
# 10300
# 10350
# 10400
# 10450
# 10500
# 10550
# 10600
# 10650
# 10700
# 10750
# 10800
# 10850
# 10900
# 10950
# 11000
# 11050
# 11100
# 11150
# 11200
# 11250
# 11300
# 11350
# 11400
# 11450
# 11500
# 11550
# 11600
# 11650
# 11700
# 11750
# 11800
# 11850
# 11900
# 11950
# 12000
# 12050
# 12100
# 12150
# 12200
# 12250
# 12300
# 12350
# 12400
# 12450
# 12500
# 12550
# 12600
# 12650
# 12700
# 12750
# 12800
# 12850
# 12900
# 12950
# 13000
# 13050
# 13100
# 13150
# 13200
# 13250
# 13300
# 13350
# 13400
# 13450
# 13500
# 13550
# 13600
# 13650
# 13700
# 13750
# 13800
# 13850
# 13900
# 13950
# 14000
# 14050
# 14100
# 14150
# 14200
# 14250
# 14300
# 14350
# 14400
# 14450
# 14500
# 14550
# 14600
# 14650
# 14700
# 14750
# 14800
# 14850
# 14900
# 14950
# 15000
# 15050
# 15100
# 15150
# 15200
# 15250
# 15300
# 15350
# 15400
# 15450
# 15500
# 15550
# 15600
# 15650
# 15700
# 15750
# 15800
# 15850
# 15900
# 15950
# 16000
# 16050
# 16100
# 16150
# 16200
# 16250
# 16300
# 16350
# 16400
# 16450
# 16500
# 16550
# 16600
# 16650
# 16700
# 16750
# 16800
# 16850
# 16900
# 16950
# 17000
# 17050
# 17100
# 17150
# 17200
# 17250
# 17300
# 17350
# 17400
# 17450
# 17500
# 17550
# 17600
# 17650
# 17700
# 17750
# 17800
# 17850
# 17900
# 17950
# 18000
# 18050
# 18100
# 18150
# 18200
# 18250
# 18300
# 18350
# 18400
# 18450
# 18500
# 18550
# 18600
# 18650
# 18700
# 18750
# 18800
# 18850
# 18900
# 18950
# 19000
# 19050

# %%
# new_data = pd.read_csv('sum_data.csv')
# new_data = pd.concat([new_data, sum_data])
# new_data.to_csv('sum_data.csv')
sum_data.head()
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE     GAME_ID  GAME_STATUS_ID  \
# 0  2016-02-24T00:00:00              1  0021500845               3
# 0  2016-02-21T00:00:00              5  0021500827               3
# 0  2016-02-10T00:00:00              1  0021500789               3
# 0  2016-02-08T00:00:00              1  0021500774               3
# 0  2016-02-06T00:00:00              2  0021500761               3
#
#   GAME_STATUS_TEXT         GAMECODE  HOME_TEAM_ID  VISITOR_TEAM_ID SEASON  \
# 0            Final  20160224/CHACLE    1610612739       1610612766   2015
# 0            Final  20160221/CHABKN    1610612751       1610612766   2015
# 0            Final  20160210/CHAIND    1610612754       1610612766   2015
# 0            Final  20160208/CHICHA    1610612766       1610612741   2015
# 0            Final  20160206/WASCHA    1610612766       1610612764   2015
#
#    LIVE_PERIOD LIVE_PC_TIME NATL_TV_BROADCASTER_ABBREVIATION  \
# 0            4                                          None
# 0            4                                          None
# 0            4                                          None
# 0            4                                          None
# 0            4                                          None
#
#   LIVE_PERIOD_TIME_BCAST  WH_STATUS
# 0                 Q4  -           1
# 0                 Q4  -           1
# 0                 Q4  -           1
# 0                 Q4  -           1
# 0                 Q4  -           1

# %%
def get_refs(game_id):
    game_data_sum = boxscoresummaryv2.BoxScoreSummaryV2(game_id=game_id, headers=headers, timeout=100)
    df_refs = game_data_sum.officials.get_data_frame()
    lst_refs = df_refs.values.tolist()
    for i in range(len(lst_refs)):
        lst_refs[i].append(game_id)
    return lst_refs

# %%
ref_data = []
for i in range(8801, len(game_ids)):
    game_refs = get_refs(game_ids[i])
    ref_data.extend(game_refs)

    if i % 200 == 0:
        print(i)
# Out:
# 9000
# 9200
# 9400
# 9600
# 9800
# 10000
# 10200
# 10400
# 10600
# 10800
# 11000
# 11200
# 11400
# 11600
# 11800
# 12000
# 12200
# 12400
# 12600
# 12800
# 13000
# 13200
# 13400
# 13600
# 13800
# 14000
# 14200
# 14400
# 14600
# 14800
# 15000
# 15200
# 15400
# 15600
# 15800
# 16000
# 16200
# 16400
# 16600
# 16800
# 17000
# 17200
# 17400
# 17600
# 17800
# 18000
# 18200
# 18400
# 18600
# 18800
# 19000

# %%
old_ref = pd.read_csv('ref_data.csv')
old_ref = old_ref.drop(columns=['Unnamed: 0'])
new_ref = pd.DataFrame(ref_data)
new_ref.columns = ['0', '1', '2', '3', '4']
final_ref = pd.concat([old_ref, new_ref], axis=0, ignore_index=True)
final_ref.to_csv('ref_data.csv')
final_ref.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57184 entries, 0 to 57183
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       57184 non-null  int64
#  1   1       57184 non-null  object
#  2   2       57184 non-null  object
#  3   3       57184 non-null  object
#  4   4       57184 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 2.2+ MB

# %%
import requests
import os

# %%
apiKey = 

sport = 'basketball_nba'
date = '2023-11-07T00:40:00Z'

# %%
event_response = requests.get(
    f'https://api.the-odds-api.com//v4/historical/sports/{sport}/events?apiKey={apiKey}&date={date}',
)
if event_response.status_code == 200:
    odds_json = event_response.json()
else:
    print(f'Failed to get odds: status_code {event_response.status_code}, response body {event_response.text}')

# %%
odds_json
# Out:
# {'timestamp': '2023-11-07T00:35:42Z',
#  'previous_timestamp': '2023-11-07T00:30:43Z',
#  'next_timestamp': '2023-11-07T00:40:42Z',
#  'data': [{'id': '88b6c95aa5c16857922d78700d0a11fa',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-11-07T00:10:00Z',
#    'home_team': 'Orlando Magic',
#    'away_team': 'Dallas Mavericks'},
#   {'id': '3dc423d708b971aac9e77ac7b206ad73',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-11-07T00:10:32Z',
#    'home_team': 'Indiana Pacers',
#    'away_team': 'San Antonio Spurs'},
#   {'id': '69644724ea2b68cb009079f406db54e3',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-11-07T00:10:39Z',
#    'home_team': 'Detroit Pistons',
#    'away_team': 'Golden State Warriors'},
#   {'id': '4ef2d407cd6d9b3352624148f8336c68',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-11-07T00:10:55Z',
#    'home_team': 'Philadelphia 76ers',
#    'away_team': 'Washington Wizards'},
#   {'id': 'e6a2441741193c6f65b5263b25f83d7a',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-11-07T00:40:00Z',
#    'home_team': 'Brooklyn Nets',
#    'away_team': 'Milwaukee Bucks'},
#   {'id': 'c0a8b33495b752741400cdb04f83c141',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-11-07T00:40:00Z',
#    'home_team': 'New York Knicks',
#    'away_team': 'Los Angeles Clippers'},
#   {'id': '115a32544666157f8090bc68618c60a9',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-11-07T00:40:00Z',
#    'home_team': 'Miami Heat',
#    'away_team': 'Los Angeles Lakers'},
#   {'id': 'f81c7ab45d12bc980eddf4faa28efe54',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-11-07T01:10:00Z',
#    'home_team': 'Oklahoma City Thunder',
#    'away_team': 'Atlanta Hawks'},
#   {'id': 'a5545c416acbf3f731394641280d7522',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-11-07T01:10:00Z',
#    'home_team': 'Minnesota Timberwolves',
#    'away_team': 'Boston Celtics'},
#   {'id': 'f4e8ea18ce92a56bc1ff318663821cdd',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-11-07T01:10:00Z',
#    'home_team': 'Chicago Bulls',
#    'away_team': 'Utah Jazz'},
#   {'id': '48eea83c50cf4d67421e5032b6c59238',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-11-07T01:10:00Z',
#    'home_team': 'Houston Rockets',
#    'away_team': 'Sacramento Kings'},
#   {'id': 'b1e0b2b7ff329898a4ae350ac5eb35ab',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-11-07T02:10:00Z',
#    'home_team': 'Denver Nuggets',
#    'away_team': 'New Orleans Pelicans'},
#   {'id': '5a4b28938902c4fba16da19c6e8c1296',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-12-25T17:00:00Z',
#    'home_team': 'New York Knicks',
#    'away_team': 'Milwaukee Bucks'},
#   {'id': '20fc47de6083f99da2027876dfebadb7',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-12-25T19:30:00Z',
#    'home_team': 'Denver Nuggets',
#    'away_team': 'Golden State Warriors'},
#   {'id': '9cb979b834e23b9dc8737eebba4db760',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-12-25T22:00:00Z',
#    'home_team': 'Los Angeles Lakers',
#    'away_team': 'Boston Celtics'},
#   {'id': '184da460295c1cfd98b0ff31e8fc2b13',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-12-26T01:00:00Z',
#    'home_team': 'Miami Heat',
#    'away_team': 'Philadelphia 76ers'},
#   {'id': '96d0c38f9eae8242f2e363bdedd90c53',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-12-26T03:30:00Z',
#    'home_team': 'Phoenix Suns',
#    'away_team': 'Dallas Mavericks'}]}

# %%
events = []
for event in odds_json['data']:
    event_id = event['id']
    commence_time = event['commence_time']
    home_team = event['home_team']
    away_team = event['away_team']

    events.append([event_id, commence_time, home_team, away_team])

events_df = pd.DataFrame(events)

# %%
all_events = pd.concat([all_events, events_df])

# %%
date = all_events[1].iloc[-1]
date
# Out:
# '2024-06-18T00:40:00Z'

# %%
all_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1809 entries, 0 to 0
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       1809 non-null   object
#  1   1       1809 non-null   object
#  2   2       1809 non-null   object
#  3   3       1809 non-null   object
# dtypes: object(4)
# memory usage: 70.7+ KB

# %%
for i in range(5):
    event_response = requests.get(
        f'https://api.the-odds-api.com//v4/historical/sports/{sport}/events?apiKey={apiKey}&date={date}',
    )
    if event_response.status_code == 200:
        odds_json = event_response.json()
    else:
        print(f'Failed to get odds: status_code {event_response.status_code}, response body {event_response.text}')
    
    events = []
    for event in odds_json['data']:
        event_id = event['id']
        commence_time = event['commence_time']
        home_team = event['home_team']
        away_team = event['away_team']

        events.append([event_id, commence_time, home_team, away_team])

    events_df = pd.DataFrame(events)
    all_events = pd.concat([all_events, events_df])
    date = all_events[1].iloc[-1]
    print(i)

all_events.info()
# Out:
# 0
# 1
# 2
# 3
# 4
# <class 'pandas.core.frame.DataFrame'>
# Index: 1804 entries, 0 to 0
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       1804 non-null   object
#  1   1       1804 non-null   object
#  2   2       1804 non-null   object
#  3   3       1804 non-null   object
# dtypes: object(4)
# memory usage: 70.5+ KB

# %%
all_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1810 entries, 0 to 0
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       1810 non-null   object
#  1   1       1810 non-null   object
#  2   2       1810 non-null   object
#  3   3       1810 non-null   object
# dtypes: object(4)
# memory usage: 70.7+ KB

# %%
all_events.to_csv('events.csv')

# %%
events_info = pd.read_csv('events.csv')
events_info = events_info.drop(columns=['Unnamed: 0'])
events_info = events_info.drop_duplicates()

# %%
events_info.iloc[40:50]
# Out:
#                                    0                     1  \
# 47  df65d43286f345b284c706cffd7ba17e  2023-05-30T00:30:00Z
# 48  7c21e4f48eeb70e19f7932c0760b2f1b  2023-06-02T00:30:00Z
# 49  047095505c9c25015b083f6e1c68ea23  2023-06-05T00:00:00Z
# 50  69623f443d3a43b18a90221f1ced9ea2  2023-06-08T00:30:00Z
# 51  1b1a88e54d833b43de000f9e6263a60e  2023-06-10T00:30:00Z
# 52  f60db88622dc591abd922d97da63f34a  2023-06-13T00:30:00Z
# 53  fd55db2fa9ee5be1f108be5151e2ecb0  2023-10-24T23:00:00Z
# 54  a44e83dd9ce3f2317ec644774daa859b  2023-10-24T23:00:00Z
# 55  184da460295c1cfd98b0ff31e8fc2b13  2023-12-25T16:00:00Z
# 56  5a4b28938902c4fba16da19c6e8c1296  2023-12-25T16:00:00Z
#
#                         2                   3
# 47         Boston Celtics          Miami Heat
# 48         Denver Nuggets          Miami Heat
# 49         Denver Nuggets          Miami Heat
# 50             Miami Heat      Denver Nuggets
# 51             Miami Heat      Denver Nuggets
# 52         Denver Nuggets          Miami Heat
# 53         Denver Nuggets  Los Angeles Lakers
# 54  Golden State Warriors        Phoenix Suns
# 55             Miami Heat  Philadelphia 76ers
# 56        New York Knicks     Milwaukee Bucks

# %%
apiKey = '0472e2e243597df61ff8139f6a2841ab'

sport = 'basketball_nba'
date = '2023-12-24T00:40:00Z'

# %%
event_response = requests.get(
    f'https://api.the-odds-api.com//v4/historical/sports/{sport}/events?apiKey={apiKey}&date={date}',
)
if event_response.status_code == 200:
    odds_json = event_response.json()
else:
    print(f'Failed to get odds: status_code {event_response.status_code}, response body {event_response.text}')

# %%
odds_json
# Out:
# {'timestamp': '2023-12-24T00:35:38Z',
#  'previous_timestamp': '2023-12-24T00:30:38Z',
#  'next_timestamp': '2023-12-24T00:40:38Z',
#  'data': [{'id': 'd5c718e775d1e9ee0e3b2bbc24fbc5fb',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-12-24T00:10:00Z',
#    'home_team': 'New Orleans Pelicans',
#    'away_team': 'Houston Rockets'},
#   {'id': '7c896c95526cd2232172b564a27ac4f9',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-12-24T00:10:00Z',
#    'home_team': 'Indiana Pacers',
#    'away_team': 'Orlando Magic'},
#   {'id': '47cc3ceaf582e5c4275d3e4aa3f57c46',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-12-24T00:10:54Z',
#    'home_team': 'Charlotte Hornets',
#    'away_team': 'Denver Nuggets'},
#   {'id': 'a6f1107ca15f65b4bd7887ca11ef80ee',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-12-24T00:40:00Z',
#    'home_team': 'Atlanta Hawks',
#    'away_team': 'Memphis Grizzlies'},
#   {'id': '6dabd18accf99d9c5133d56ad9b0ea38',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-12-24T00:40:00Z',
#    'home_team': 'Brooklyn Nets',
#    'away_team': 'Detroit Pistons'},
#   {'id': '31a4136ed3ee22ce997bd23103d2c682',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-12-24T00:40:00Z',
#    'home_team': 'Toronto Raptors',
#    'away_team': 'Utah Jazz'},
#   {'id': '43d03fbd22e26bf2f365898f05b6f8d7',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-12-24T01:00:00Z',
#    'home_team': 'Chicago Bulls',
#    'away_team': 'Cleveland Cavaliers'},
#   {'id': '719105352c7dc3e657d2127d172cd90a',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-12-24T01:10:00Z',
#    'home_team': 'Oklahoma City Thunder',
#    'away_team': 'Los Angeles Lakers'},
#   {'id': '118304f978b0732968df8edc010ed96a',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-12-24T01:40:00Z',
#    'home_team': 'Dallas Mavericks',
#    'away_team': 'San Antonio Spurs'},
#   {'id': '7f3996cc5976eb307b77e036081da9fb',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-12-24T01:40:00Z',
#    'home_team': 'Golden State Warriors',
#    'away_team': 'Portland Trail Blazers'},
#   {'id': 'a44b967e74012a10d7e9c6a3f4570c8f',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-12-24T03:10:00Z',
#    'home_team': 'Sacramento Kings',
#    'away_team': 'Minnesota Timberwolves'},
#   {'id': '5a4b28938902c4fba16da19c6e8c1296',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-12-25T17:00:00Z',
#    'home_team': 'New York Knicks',
#    'away_team': 'Milwaukee Bucks'},
#   {'id': '20fc47de6083f99da2027876dfebadb7',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-12-25T19:30:00Z',
#    'home_team': 'Denver Nuggets',
#    'away_team': 'Golden State Warriors'},
#   {'id': '9cb979b834e23b9dc8737eebba4db760',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-12-25T22:00:00Z',
#    'home_team': 'Los Angeles Lakers',
#    'away_team': 'Boston Celtics'},
#   {'id': '184da460295c1cfd98b0ff31e8fc2b13',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-12-26T01:00:00Z',
#    'home_team': 'Miami Heat',
#    'away_team': 'Philadelphia 76ers'},
#   {'id': '96d0c38f9eae8242f2e363bdedd90c53',
#    'sport_key': 'basketball_nba',
#    'sport_title': 'NBA',
#    'commence_time': '2023-12-26T03:30:00Z',
#    'home_team': 'Phoenix Suns',
#    'away_team': 'Dallas Mavericks'}]}

# %%
sport = 'basketball_nba'
regions = 'us'
markets = 'player_points'
date_format = 'iso'
odds_format = 'decimal'
books = 'draftkings'
date = '2023-12-24T00:10:00Z'
event_id = 'd5c718e775d1e9ee0e3b2bbc24fbc5fb'

# %%
# https://api.the-odds-api.com/v4/historical/sports/basketball_nba/events/48dbd6bbfeb72fae383de550504df9cc/odds?apiKey=0472e2e243597df61ff8139f6a2841ab&regions=us&markets=player_points&dateFormat=iso&oddsFormat=decimal&bookmakers=draftkings%2C%20fanduel%2C%20bovada%2C%20pinnacle%2C%20betmgm%2C%20betonlineag&date=2024-06-18T00%3A30%3A00Z

odds_response = requests.get(
    f'https://api.the-odds-api.com/v4/historical/sports/{sport}/events/{event_id}/odds?apiKey={apiKey}&regions={regions}&markets={markets}&dateFormat={date_format}&oddsFormat={odds_format}&bookmakers={books}&date={date}',
)
if odds_response.status_code == 200:
    odds_json = odds_response.json()
else:
    print(f'Failed to get odds: status_code {event_response.status_code}, response body {event_response.text}')

# %%
odds_json['data']
# Out:
# {'id': 'd5c718e775d1e9ee0e3b2bbc24fbc5fb',
#  'sport_key': 'basketball_nba',
#  'sport_title': 'NBA',
#  'commence_time': '2023-12-24T00:10:00Z',
#  'home_team': 'New Orleans Pelicans',
#  'away_team': 'Houston Rockets',
#  'bookmakers': [{'key': 'draftkings',
#    'title': 'DraftKings',
#    'last_update': '2023-12-24T00:05:34Z',
#    'markets': [{'key': 'player_points',
#      'last_update': '2023-12-24T00:05:17Z',
#      'outcomes': [{'name': 'Over',
#        'description': 'Alperen Sengun',
#        'price': 1.83,
#        'point': 17.5},
#       {'name': 'Under',
#        'description': 'Alperen Sengun',
#        'price': 1.91,
#        'point': 17.5},
#       {'name': 'Over',
#        'description': 'Brandon Ingram',
#        'price': 1.87,
#        'point': 22.5},
#       {'name': 'Under',
#        'description': 'Brandon Ingram',
#        'price': 1.87,
#        'point': 22.5},
#       {'name': 'Over',
#        'description': 'CJ McCollum',
#        'price': 1.8,
#        'point': 16.5},
#       {'name': 'Under',
#        'description': 'CJ McCollum',
#        'price': 1.95,
#        'point': 16.5},
#       {'name': 'Over',
#        'description': 'Dillon Brooks',
#        'price': 2.0,
#        'point': 13.5},
#       {'name': 'Under',
#        'description': 'Dillon Brooks',
#        'price': 1.77,
#        'point': 13.5},
#       {'name': 'Over',
#        'description': 'Fred VanVleet',
#        'price': 1.95,
#        'point': 17.5},
#       {'name': 'Under',
#        'description': 'Fred VanVleet',
#        'price': 1.8,
#        'point': 17.5},
#       {'name': 'Over',
#        'description': 'Herbert Jones',
#        'price': 2.0,
#        'point': 9.5},
#       {'name': 'Under',
#        'description': 'Herbert Jones',
#        'price': 1.77,
#        'point': 9.5},
#       {'name': 'Over',
#        'description': 'Jabari Smith Jr.',
#        'price': 2.0,
#        'point': 14.5},
#       {'name': 'Under',
#        'description': 'Jabari Smith Jr.',
#        'price': 1.77,
#        'point': 14.5},
#       {'name': 'Over',
#        'description': 'Jalen Green',
#        'price': 1.91,
#        'point': 17.5},
#       {'name': 'Under',
#        'description': 'Jalen Green',
#        'price': 1.83,
#        'point': 17.5},
#       {'name': 'Over',
#        'description': 'Jonas Valanciunas',
#        'price': 1.95,
#        'point': 14.5},
#       {'name': 'Under',
#        'description': 'Jonas Valanciunas',
#        'price': 1.8,
#        'point': 14.5},
#       {'name': 'Over',
#        'description': 'Tari Eason',
#        'price': 1.87,
#        'point': 10.5},
#       {'name': 'Under',
#        'description': 'Tari Eason',
#        'price': 1.87,
#        'point': 10.5},
#       {'name': 'Over',
#        'description': 'Trey Murphy III',
#        'price': 1.95,
#        'point': 13.5},
#       {'name': 'Under',
#        'description': 'Trey Murphy III',
#        'price': 1.8,
#        'point': 13.5},
#       {'name': 'Over',
#        'description': 'Zion Williamson',
#        'price': 1.91,
#        'point': 22.5},
#       {'name': 'Under',
#        'description': 'Zion Williamson',
#        'price': 1.83,
#        'point': 22.5}]}]}]}

# %%
event_id_m = []
dates = []
names = []
descriptions = []
prices = []
points = []

for line in odds_json['data']['bookmakers'][0]['markets'][0]['outcomes']:
    event_id_m.append(event_id)
    dates.append(date)
    names.append(line['name'])
    descriptions.append(line['description'])
    prices.append(line['price'])
    points.append(line['point'])

odds_data = pd.DataFrame({
    'event_id': event_id_m,
    'date': dates,
    'o/u': names,
    'player': descriptions,
    'price': prices,
    'line': points
})

# %%
old = pd.read_csv('more_point_odds_data.csv')
old = old.drop(columns=['Unnamed: 0'])
up = pd.concat([old, odds_data], ignore_index=True)
up.to_csv('more_point_odds_data.csv')

# %%
'3d4c502f3ca5f026ab17bcaf740a0737' in events_info['0']
# Out:
# False

# %%
# for i in range(len(events_info)):
#     event_id = events_info['0'].iloc[i]
#     date = events_info['1'].iloc[i]
#     odds_response = requests.get(
#         f'https://api.the-odds-api.com/v4/historical/sports/{sport}/events/{event_id}/odds?apiKey={apiKey}&regions={regions}&markets={markets}&dateFormat={date_format}&oddsFormat={odds_format}&bookmakers={books}&date={date}',
#     )
#     if odds_response.status_code == 200:
#         odds_json = odds_response.json()
#     else:
#         print(f'Failed to get odds: status_code {odds_response.status_code}, response body {odds_response.text}')
    
#     for line in odds_json['data']['bookmakers'][0]['markets'][0]['outcomes']:
#         event_id_m.append(event_id)
#         dates.append(date)
#         names.append(line['name'])
#         descriptions.append(line['description'])
#         prices.append(line['price'])
#         points.append(line['point'])
        
#     if i % 50 == 0:
#         print(i)
# Out:
# Failed to get odds: status_code 404, response body {"message":"Event not found. The event may have expired or the event id is invalid.","error_code":"EVENT_NOT_FOUND","details_url":"https://the-odds-api.com/liveapi/guides/v4/api-error-codes.html#event-not-found"}
#
# 0
# Failed to get odds: status_code 404, response body {"message":"Event not found. The event may have expired or the event id is invalid.","error_code":"EVENT_NOT_FOUND","details_url":"https://the-odds-api.com/liveapi/guides/v4/api-error-codes.html#event-not-found"}
#
# 50
# Failed to get odds: status_code 404, response body {"message":"Event not found. The event may have expired or the event id is invalid.","error_code":"EVENT_NOT_FOUND","details_url":"https://the-odds-api.com/liveapi/guides/v4/api-error-codes.html#event-not-found"}
#
# 100
# 150
# 200
# 250
# Failed to get odds: status_code 404, response body {"message":"Event not found. The event may have expired or the event id is invalid.","error_code":"EVENT_NOT_FOUND","details_url":"https://the-odds-api.com/liveapi/guides/v4/api-error-codes.html#event-not-found"}
#
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200

# %%
odds_data = pd.DataFrame({
    'event_id': event_id_m,
    'date': dates,
    'o/u': names,
    'player': descriptions,
    'price': prices,
    'line': points
})

# %%
odds_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32023 entries, 0 to 32022
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   event_id  32023 non-null  object
#  1   date      32023 non-null  object
#  2   o/u       32023 non-null  object
#  3   player    32023 non-null  object
#  4   price     32023 non-null  float64
#  5   line      32023 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 1.5+ MB

# %%
odds_data.to_csv('point_odds_data.csv')
